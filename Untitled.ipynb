# %%
/usr/local/kafka/bin/kafka-topics.sh --list --bootstrap-server broker:9092
# Out:
#   Cell In[1], line 1
#     usr/local/kafka/bin/kafka-topics.sh(--list, --bootstrap-server, broker:9092)
#                                                                           ^
# SyntaxError: invalid syntax
