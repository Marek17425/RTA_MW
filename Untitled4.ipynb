# %%
cd ~/notebooks   # upewnij się, że jesteś w katalogu z plikami
# Out:
# [Errno 2] No such file or directory: '/home/jovyan/notebooks # upewnij się, że jesteś w katalogu z plikami'
# /home/jovyan/notebooks

# %%
git add producer.py consumer_filter.py scoring_consumer.py consumer_count.py
# Out:
#   Cell In[2], line 1
#     git add producer.py consumer_filter.py scoring_consumer.py consumer_count.py
#         ^
# SyntaxError: invalid syntax
